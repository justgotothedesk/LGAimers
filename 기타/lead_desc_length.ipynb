# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
selected_columns = [
    'bant_submit', 'customer_country', 'business_unit', 'com_reg_ver_win_rate',
    'customer_idx', 'customer_type', 'enterprise', 'historical_existing_cnt',
    'id_strategic_ver', 'it_strategic_ver', 'idit_strategic_ver', 'customer_job',
    'lead_desc_length', 'inquiry_type', 'product_category', 'product_subcategory',
    'product_modelname', 'customer_country.1', 'customer_position',
    'response_corporate', 'expected_timeline', 'ver_cus', 'ver_pro',
    'ver_win_rate_x', 'ver_win_ratio_per_bu', 'business_area', 'business_subarea',
    'lead_owner'
]

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_file_path = '/content/drive/MyDrive/LGdata/train.csv'

df = pd.read_csv(train_file_path)

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
ratio_df_lead_desc_length = ratio_df_lead_desc_length.sort_values(by='conversion_ratio', ascending=False)

for index, row in ratio_df_lead_desc_length.iterrows():
    lead_desc_length_bin = row['lead_desc_length_bin']
    total = int(row['is_converted_y'])
    converted = int(row['is_converted_x'])
    ratio = row['conversion_ratio'] * 100
    print(f"Lead Description Length: {lead_desc_length_bin}\nTotal: {total}\nConverted: {converted}\nConversion Ratio: {ratio:.2f}%\n")

plt.figure(figsize=(12, 6))

bars = plt.bar(ratio_df_lead_desc_length['lead_desc_length_bin'], ratio_df_lead_desc_length['conversion_ratio'], color='blue', alpha=0.7)

plt.title('Conversion Ratio by Lead Description Length', fontsize=16)
plt.xlabel('Lead Description Length (bins of 100 characters up to 1300)', fontsize=14)
plt.ylabel('Conversion Ratio (%)', fontsize=14)

plt.xticks(rotation='vertical')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...
